# %%
import numpy as np
import pandas as pd
import scipy
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # QUESTION 1

# %%
pop1 = np.random.binomial(10, 0.2, 10000)
pop2 = np.random.binomial(10,0.5, 10000) 


plt.hist(pop1, alpha=0.5, label='Population 1') 
plt.hist(pop2, alpha=0.5, label='Population 2') 
plt.legend(loc='upper right') 
plt.show()

# %%
# I predict that by making the sample sizes greater, the difference between the means will decrease, which means the standard
# error between means will decrease. The opposite will be true with a smaller sample size: the means are more likely to have a
# big difference, but the standard deviations shouldn't change too much


sample1 = np.random.choice(pop1, 20, replace=True)
sample2 = np.random.choice(pop2, 20, replace=True)
plt.hist(sample1, alpha=.05, label='sample1', color='blue')
plt.hist(sample2, alpha=.05, label='sample2', color = 'red')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample1.mean())
print(sample2.mean())
print(sample1.std())
print(sample2.std())
# Out:
# 2.05
# 4.55
# 1.24398553046
# 1.82961744635

# %%
diff = sample2.mean() - sample1.mean()
print(diff)
# Out:
# 2.5

# %%
import math
size = np.array([len(sample1), len(sample2)])
sd = np.array([sample1.std(), sample2.std()])

diff_stand_err = math.sqrt(sum(sd ** 2 / size))
print(diff/diff_stand_err)
# Out:
# 5.05334161633

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample1, sample2, equal_var=False))
# Out:
# Ttest_indResult(statistic=-4.9253881488418543, pvalue=2.2236969567794932e-05)

# %% [markdown]
# # QUESTION 2

# %%
# Playing around with it, it seems that by making the p value larger
# the difference between the means of the sample sizes gets smaller.
# This makes sense, as p value in the binomial distribution is probability of success,
# so the higher the probability of success in

# %%
pop3 = np.random.binomial(10, 0.2, 10000)
pop4 = np.random.binomial(10,0.5, 10000) 

print(pop3.mean())
print(pop3.std())
print(pop4.mean())
print(pop4.std())
# Out:
# 1.9958
# 1.2725495511
# 4.9882
# 1.59149639019

# %%
sample3 = np.random.choice(pop1, 100, replace=True)
sample4 = np.random.choice(pop2, 100, replace=True)

plt.hist(sample3, alpha=.05, label='sample 3', color = 'blue')
plt.hist(sample4, alpha=.05, label='sample 4', color ='red')
plt.legend(loc='upper right')
plt.show()

# %%
print(sample3.mean())
# Out:
# 2.03

# %%
diff = sample4.mean() - sample3.mean()
print(diff)
# Out:
# 3.12

# %%
import math
size = np.array([len(sample3), len(sample4)])
sd = np.array([sample3.std(), sample4.std()])

diff_stand_err = math.sqrt(sum(sd ** 2 / size))
print(diff/diff_stand_err)
# Out:
# 15.5291160717

# %%
from scipy.stats import ttest_ind
print(ttest_ind(sample4, sample3, equal_var=False))
# Out:
# Ttest_indResult(statistic=15.451275400745612, pvalue=3.0113153719265647e-34)
